# %%
import pandas as pd

# %%
df=pd.read_csv('userdata.csv')
df
# Out:
#    Unnamed: 0  marksa  marksb  marksc
# 0           0      73      92       2
# 1           1      51      77      18
# 2           2      24      21      48
# 3           3      32      22      74
# 4           4      52      90       1
# 5           5      54      21      75
# 6           6      46       5       2
# 7           7      71      30      83
# 8           8      15      75      11
# 9           9      13      56      20

# %%
df=df.drop(columns=['Unnamed: 0'])

# %%
type(df.iloc[3])
# Out:
# pandas.core.series.Series

# %%
type(df.iloc[3].values)
# Out:
# numpy.ndarray

# %%
idx=df.columns.get_loc('marksb')
print(idx)
df.iloc[3,idx]
# Out:
# 1
# 22

# %%
df.iloc[:3,[1,2]]
# Out:
#    marksb  marksc
# 0      92       2
# 1      77      18
# 2      21      48

# %%
# sorting
print(df)
df.sort_values(by=['marksa','marksc'],ascending=False)
# Out:
#    marksa  marksb  marksc
# 0      73      92       2
# 1      51      77      18
# 2      24      21      48
# 3      32      22      74
# 4      52      90       1
# 5      54      21      75
# 6      46       5       2
# 7      71      30      83
# 8      15      75      11
# 9      13      56      20
#    marksa  marksb  marksc
# 0      73      92       2
# 7      71      30      83
# 5      54      21      75
# 4      52      90       1
# 1      51      77      18
# 6      46       5       2
# 3      32      22      74
# 2      24      21      48
# 8      15      75      11
# 9      13      56      20

# %%
df.values # dataframe to numy arrays
# Out:
# array([[73, 92,  2],
#        [51, 77, 18],
#        [24, 21, 48],
#        [32, 22, 74],
#        [52, 90,  1],
#        [54, 21, 75],
#        [46,  5,  2],
#        [71, 30, 83],
#        [15, 75, 11],
#        [13, 56, 20]], dtype=int64)

# %%
#numpy to data frame
new_=pd.DataFrame(df.values)

# %%
new_
# Out:
#     0   1   2
# 0  73  92   2
# 1  51  77  18
# 2  24  21  48
# 3  32  22  74
# 4  52  90   1
# 5  54  21  75
# 6  46   5   2
# 7  71  30  83
# 8  15  75  11
# 9  13  56  20

# %%
new_withcolumn=pd.DataFrame(df.values,columns=['marksa','markb','markc'])

# %%
new_withcolumn
# Out:
#    marksa  markb  markc
# 0      73     92      2
# 1      51     77     18
# 2      24     21     48
# 3      32     22     74
# 4      52     90      1
# 5      54     21     75
# 6      46      5      2
# 7      71     30     83
# 8      15     75     11
# 9      13     56     20

# %%
new_withcolumn.to_csv?
# Out:
# Signature:
# new_withcolumn.to_csv(
#     path_or_buf: 'FilePathOrBuffer[AnyStr] | None' = None,
#     sep: 'str' = ',',
#     na_rep: 'str' = '',
#     float_format: 'str | None' = None,
#     columns: 'Sequence[Hashable] | None' = None,
#     header: 'bool_t | list[str]' = True,
#     index: 'bool_t' = True,
#     index_label: 'IndexLabel | None' = None,
#     mode: 'str' = 'w',
#     encoding: 'str | None' = None,
#     compression: 'CompressionOptions' = 'infer',
#     quoting: 'int | None' = None,
#     quotechar: 'str' = '"',
#     line_terminator: 'str | None' = None,
#     chunksize: 'int | None' = None,
#     date_format: 'str | None' = None,
#     doublequote: 'bool_t' = True,
#     escapechar: 'str | None' = None,
#     decimal: 'str' = '.',
#     errors: 'str' = 'strict',
#     storage_options: 'StorageOptions' = None,
# ) -> 'str | None'
# Docstring:
# Write object to a comma-separated values (csv) file.
#
# Parameters
# ----------
# ...

# %%
new_withcolumn.to_csv('mark.csv',index=False)

# %%
pd.read_csv('mark.csv')
# Out:
#    marksa  markb  markc
# 0      73     92      2
# 1      51     77     18
# 2      24     21     48
# 3      32     22     74
# 4      52     90      1
# 5      54     21     75
# 6      46      5      2
# 7      71     30     83
# 8      15     75     11
# 9      13     56     20
