# %%
import numpy as np

# %%
prices=np.arange(500,10000,500)

# %%
prices
# Out:
# array([ 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500,
#        6000, 6500, 7000, 7500, 8000, 8500, 9000, 9500])

# %%
# if only one value is given, it is used as y and x is 0,1,2,3,...

# %%
#scatter plots
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))
plt.scatter(prices,prices**2,label='prices squared',marker='>')
plt.legend()
plt.show()
